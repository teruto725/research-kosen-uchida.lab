# %%
import numpy as np
import pandas as pd

# %%
#script内を実行する
from scripts import increase_dataset as s1

# %%
from scripts import create_mcs_csv as s2

# %%
from scripts import create_feature as s3

# %%
# 必要なデータをインポートする
exp_data = pd.read_csv("./human_exp/exp_data.csv")
wordnet_data = pd.read_csv("./dataset/wordnet.csv")
data = pd.read_csv("./dataset/dataset_relation.csv")

# %%
#被験者用データと結合
marged_data = pd.merge(exp_data,data)

# %%
marged_data
# Out:
#                class_a     class_b relation ans_yamasaki ans_ueda ans_daisuke  \
# 0               racket        ball        k            k        k           k
# 1                block        ball        k            k        k           k
# 2               player        beam        k           h2       s2           k
# 3                alien        shot        k            k       s2           k
# 4            bar_block       block       h1           s1       h1          h1
# ..                 ...         ...      ...          ...      ...         ...
# 255        brake_pedal       pedal       h1           h1       h1          h1
# 256             driver  automobile        k            k        k          s1
# 257              pedal  automobile       s1           h1       s1          s1
# 258  automobile_engine  automobile       s1           h1       s1          s1
# 259        speedometer  automobile       s1           h1       s1          s1
#
#     ans_hosomi ans_kazuma ans_sugi     type         title      source
# 0            k          k       h1  program    brockbreak  swing_game
# 1           h2         s2        k  program    brockbreak  swing_game
# 2           s2         s2        k  program       invador  swing_game
# 3           s2          k        k  program       invador  swing_game
# 4           h1         h2       h1  program        tetris  swing_game
# ..         ...        ...      ...      ...           ...         ...
# 255         h1         h1       h1  analyse  auto_system1          me
# 256         h2          k        k  analyse  auto_system2          me
# 257          k         s1       s1  analyse  auto_system2          me
# 258         s1         s1       s1  analyse  auto_system2          me
# 259          k         s1       s1  analyse  auto_system2          me
#
# [260 rows x 12 columns]

# %%
#dataのかさまし
reverse_labels = {'ans_ueda',
       'ans_daisuke', 'ans_kazuma', 'ans_sugi',"ans_yamasaki","ans_hosomi"}
data1 = s1.execute(marged_data,reverse_labels)
data1.to_csv("./exec_backup/data1.csv")

# %%
#mcspickle作成
s2.execute(wordnet_data)
# Out:
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/akihito/.pyenv/versions/3.8.5/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'concept.research.microsoft.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
exp_data = s3.execute(data1,wordnet_data)
# Out:
# Start
# Lexvec is completed
# Wiki2vec is completed
# Wordnet is completed
# Mcg is completed
# Setup sequence is all green
# Proceed to creating feature sequence
# All feature is completed
#                 class_a             class_b relation ans_yamasaki ans_ueda  \
# 0        customer_hobby            customer       s1           h1       s1
# 1              customer     customer_system        k           h2       s1
# 2       customer_system       administrator        k            k       s2
# 3    merchant_interface       administrator        k            k        k
# 4              merchant  merchant_interface        k           h2       s2
# ..                  ...                 ...      ...          ...      ...
# 420             company                team       s2           h2        k
# 421                team           assistant       s2            k       s2
# 422                team              worker       s2           s2       s2
# 423            employee            engineer       h2           h2        k
# 424                team             company       s1           h1        k
#
#     ans_daisuke ans_hosomi ans_kazuma ans_sugi     type  ... wn_sim_wup  \
# 0            h1         h1         h1       s1  analyse  ...   0.562500
# 1             k         h2         h2       s1  analyse  ...   0.735294
# 2             k          k          k        k  analyse  ...   0.535294
# 3             k          k          k        k  analyse  ...   0.358824
# 4             k          k         h2        k  analyse  ...   0.558824
# ..          ...        ...        ...      ...      ...  ...        ...
# 420          s2          k          k       s2  analyse  ...   0.714286
# 421          s2         h2         s2       s2  analyse  ...   0.153846
# 422          s2         h2         s2       s2  analyse  ...   0.166667
# 423          h2         s2         h1       h2  analyse  ...   0.705882
# 424          s1          k          k       s1  analyse  ...   0.714286
#
#     wn_sim_res     wn_sim_jcn  wn_sim_lin  has_same_word  is_include_word  \
# 0     3.903153  5.000000e+299    0.500000            1.0              0.0
# 1     4.669070  5.000000e+299    0.601895            1.0              1.0
# 2     1.932689   9.089755e-02    0.258637            0.0              0.0
# 3     1.166773   7.080691e-02    0.149058            0.0              0.0
# 4     4.140726  5.000000e+299    0.500000            1.0              1.0
# ..         ...            ...         ...            ...              ...
# 420   3.906641   1.393009e-01    0.521164            0.0              0.0
# 421   0.000000   7.403270e-02    0.000000            0.0              0.0
# 422   0.000000   8.457223e-02    0.000000            0.0              0.0
# 423   2.333545   8.768206e-02    0.290388            0.0              0.0
# 424   3.906641   1.393009e-01    0.521164            0.0              0.0
#
#      bert_sim                                        lexvec_diff  \
# 0    1.000000  [0.1353915, -0.074367, -0.024859, 0.0321785, -...
# 1    0.995861  [-0.061648004, -0.040162496, 0.046398997, 0.02...
# 2    0.966966  [-0.070198, -0.055818498, 0.18047, 0.064464, 0...
# 3    0.918205  [0.1044345, -0.126051, 0.172911, 0.005991496, ...
# 4    0.999340  [0.123124495, -0.077077, 0.075254, -0.03854949...
# ..        ...                                                ...
# 420  0.927054  [0.038026, -0.030671999, -0.115054, -0.0010729...
# 421  0.968967  [-0.083178, -0.024441, 0.087414, -0.053188004,...
# 422  0.955652  [0.016667, 0.049456, -0.007928001, -0.142308, ...
# 423  0.978564  [-0.122838005, 0.246589, 0.13669999, 0.218586,...
# 424  0.927054  [-0.038026, 0.030671999, 0.115054, 0.001072999...
#
#                                          wiki2vec_diff  \
# 0    [0.004532963, 0.039239302, -0.17118743, 0.0603...
# 1    [0.030404776, -0.04104735, 0.32204115, 0.06177...
# 2    [-0.21885814, 0.0184616, -0.34345943, 0.296956...
# 3    [-0.3109901, -0.1638336, -0.17393859, 0.277264...
# 4    [-0.105917156, 0.0655738, 0.019413382, 0.12573...
# ..                                                 ...
# 420  [0.009534836, 0.27768353, 0.1267077, -0.195739...
# 421  [-0.5358249, -0.5324029, -0.5566437, 0.208053,...
# 422  [-0.19864744, -0.35216272, -0.26205117, 0.6510...
# 423  [0.28338745, -0.08295294, -0.086619645, 0.0861...
# 424  [-0.009534836, -0.27768353, -0.1267077, 0.1957...
#
#                                              bert_diff
# 0    [-0.01283209, 0.38895035, -0.40116873, 0.21378...
# 1    [0.012832075, -0.38895035, 0.40116876, -0.2137...
# 2    [-0.6860469, -0.73245233, 0.58075726, -0.45916...
# 3    [-0.48916733, -0.16108796, -0.35653108, -0.105...
# 4    [-0.45396984, -0.27106622, -0.08016433, -0.287...
# ..                                                 ...
# 420  [3.0424602, 3.0595293, -1.8400558, 3.8036022, ...
# 421  [-2.9693716, -3.0967522, 1.9765253, -3.558187,...
# 422  [-3.0886095, -3.0115585, 1.8675127, -3.6884851...
# 423  [0.075264774, -0.11368515, 0.091799304, 0.0022...
# 424  [-3.0424602, -3.0595293, 1.8400558, -3.8036022...
#
# [425 rows x 32 columns]

# %%
exp_data.to_csv("./1_pretraind_data.csv")
